# %% [markdown]
# # Image Captioning with LSTMs
# In the previous exercise you implemented a vanilla RNN and applied it to image captioning. In this notebook you will implement the LSTM update rule and use it for image captioning.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time, os, json
import numpy as np
import matplotlib.pyplot as plt
import nltk

from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.rnn_layers import *
from cs231n.captioning_solver import CaptioningSolver
from cs231n.classifiers.rnn import CaptioningRNN
from cs231n.coco_utils import load_coco_data, sample_coco_minibatch, decode_captions
from cs231n.image_utils import image_from_url

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install nltk
# Out:
# DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
# Requirement already satisfied: nltk in /usr/local/lib/python2.7/site-packages (3.4.5)
# Requirement already satisfied: six in /usr/local/lib/python2.7/site-packages (from nltk) (1.12.0)
# Requirement already satisfied: singledispatch; python_version < "3.4" in /usr/local/lib/python2.7/site-packages (from nltk) (3.4.0.3)

# %% [markdown]
# # Load MS-COCO data
# As in the previous notebook, we will use the Microsoft COCO dataset for captioning.

# %%
# Load COCO data from disk; this returns a dictionary
# We'll work with dimensionality-reduced features for this notebook, but feel
# free to experiment with the original features by changing the flag below.
data = load_coco_data(pca_features=True)

# Print out all the keys and values from the data dictionary
for k, v in data.items():
    if type(v) == np.ndarray:
        print(k, type(v), v.shape, v.dtype)
    else:
        print(k, type(v), len(v))
# Out:
# train_captions <class 'numpy.ndarray'> (400135, 17) int32
# train_image_idxs <class 'numpy.ndarray'> (400135,) int32
# val_captions <class 'numpy.ndarray'> (195954, 17) int32
# val_image_idxs <class 'numpy.ndarray'> (195954,) int32
# train_features <class 'numpy.ndarray'> (82783, 512) float32
# val_features <class 'numpy.ndarray'> (40504, 512) float32
# idx_to_word <class 'list'> 1004
# word_to_idx <class 'dict'> 1004
# train_urls <class 'numpy.ndarray'> (82783,) <U63
# val_urls <class 'numpy.ndarray'> (40504,) <U63

# %% [markdown]
# # LSTM
# If you read recent papers, you'll see that many people use a variant on the vanialla RNN called Long-Short Term Memory (LSTM) RNNs. Vanilla RNNs can be tough to train on long sequences due to vanishing and exploding gradiants caused by repeated matrix multiplication. LSTMs solve this problem by replacing the simple update rule of the vanilla RNN with a gating mechanism as follows.
#
# Similar to the vanilla RNN, at each timestep we receive an input $x_t\in\mathbb{R}^D$ and the previous hidden state $h_{t-1}\in\mathbb{R}^H$; the LSTM also maintains an $H$-dimensional *cell state*, so we also receive the previous cell state $c_{t-1}\in\mathbb{R}^H$. The learnable parameters of the LSTM are an *input-to-hidden* matrix $W_x\in\mathbb{R}^{4H\times D}$, a *hidden-to-hidden* matrix $W_h\in\mathbb{R}^{4H\times H}$ and a *bias vector* $b\in\mathbb{R}^{4H}$.
#
# At each timestep we first compute an *activation vector* $a\in\mathbb{R}^{4H}$ as $a=W_xx_t + W_hh_{t-1}+b$. We then divide this into four vectors $a_i,a_f,a_o,a_g\in\mathbb{R}^H$ where $a_i$ consists of the first $H$ elements of $a$, $a_f$ is the next $H$ elements of $a$, etc. We then compute the *input gate* $g\in\mathbb{R}^H$, *forget gate* $f\in\mathbb{R}^H$, *output gate* $o\in\mathbb{R}^H$ and *block input* $g\in\mathbb{R}^H$ as
#
# $$
# \begin{align*}
# i = \sigma(a_i) \hspace{2pc}
# f = \sigma(a_f) \hspace{2pc}
# o = \sigma(a_o) \hspace{2pc}
# g = \tanh(a_g)
# \end{align*}
# $$
#
# where $\sigma$ is the sigmoid function and $\tanh$ is the hyperbolic tangent, both applied elementwise.
#
# Finally we compute the next cell state $c_t$ and next hidden state $h_t$ as
#
# $$
# c_{t} = f\odot c_{t-1} + i\odot g \hspace{4pc}
# h_t = o\odot\tanh(c_t)
# $$
#
# where $\odot$ is the elementwise product of vectors.
#
# In the rest of the notebook we will implement the LSTM update rule and apply it to the image captioning task.
#
# In the code, we assume that data is stored in batches so that $X_t \in \mathbb{R}^{N\times D}$, and will work with *transposed* versions of the parameters: $W_x \in \mathbb{R}^{D \times 4H}$, $W_h \in \mathbb{R}^{H\times 4H}$ so that activations $A \in \mathbb{R}^{N\times 4H}$ can be computed efficiently as $A = X_t W_x + H_{t-1} W_h$

# %% [markdown]
# # LSTM: step forward
# Implement the forward pass for a single timestep of an LSTM in the `lstm_step_forward` function in the file `cs231n/rnn_layers.py`. This should be similar to the `rnn_step_forward` function that you implemented above, but using the LSTM update rule instead.
#
# Once you are done, run the following to perform a simple test of your implementation. You should see errors around `1e-8` or less.

# %%
N, D, H = 3, 4, 5
x = np.linspace(-0.4, 1.2, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.3, 0.7, num=N*H).reshape(N, H)
prev_c = np.linspace(-0.4, 0.9, num=N*H).reshape(N, H)
Wx = np.linspace(-2.1, 1.3, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.7, 2.2, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.3, 0.7, num=4*H)

next_h, next_c, cache = lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)

expected_next_h = np.asarray([
    [ 0.24635157,  0.28610883,  0.32240467,  0.35525807,  0.38474904],
    [ 0.49223563,  0.55611431,  0.61507696,  0.66844003,  0.7159181 ],
    [ 0.56735664,  0.66310127,  0.74419266,  0.80889665,  0.858299  ]])
expected_next_c = np.asarray([
    [ 0.32986176,  0.39145139,  0.451556,    0.51014116,  0.56717407],
    [ 0.66382255,  0.76674007,  0.87195994,  0.97902709,  1.08751345],
    [ 0.74192008,  0.90592151,  1.07717006,  1.25120233,  1.42395676]])

print('next_h error: ', rel_error(expected_next_h, next_h))
print('next_c error: ', rel_error(expected_next_c, next_c))
# Out:
# next_h error:  5.7054131185818695e-09
# next_c error:  5.8143123088804145e-09

# %% [markdown]
# # LSTM: step backward
# Implement the backward pass for a single LSTM timestep in the function `lstm_step_backward` in the file `cs231n/rnn_layers.py`. Once you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-6` or less.

# %%
np.random.seed(231)

N, D, H = 4, 5, 6
x = np.random.randn(N, D)
prev_h = np.random.randn(N, H)
prev_c = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

next_h, next_c, cache = lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)

dnext_h = np.random.randn(*next_h.shape)
dnext_c = np.random.randn(*next_c.shape)

fx_h = lambda x: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fh_h = lambda h: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fc_h = lambda c: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fWx_h = lambda Wx: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fWh_h = lambda Wh: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]
fb_h = lambda b: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[0]

fx_c = lambda x: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fh_c = lambda h: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fc_c = lambda c: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fWx_c = lambda Wx: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fWh_c = lambda Wh: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]
fb_c = lambda b: lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)[1]

num_grad = eval_numerical_gradient_array

dx_num = num_grad(fx_h, x, dnext_h) + num_grad(fx_c, x, dnext_c)
dh_num = num_grad(fh_h, prev_h, dnext_h) + num_grad(fh_c, prev_h, dnext_c)
dc_num = num_grad(fc_h, prev_c, dnext_h) + num_grad(fc_c, prev_c, dnext_c)
dWx_num = num_grad(fWx_h, Wx, dnext_h) + num_grad(fWx_c, Wx, dnext_c)
dWh_num = num_grad(fWh_h, Wh, dnext_h) + num_grad(fWh_c, Wh, dnext_c)
db_num = num_grad(fb_h, b, dnext_h) + num_grad(fb_c, b, dnext_c)

dx, dh, dc, dWx, dWh, db = lstm_step_backward(dnext_h, dnext_c, cache)

print('dx error: ', rel_error(dx_num, dx))
print('dh error: ', rel_error(dh_num, dh))
print('dc error: ', rel_error(dc_num, dc))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  6.141372523522652e-10
# dh error:  3.0914746081903265e-10
# dc error:  1.5221795880129153e-10
# dWx error:  1.6933646448886643e-09
# dWh error:  4.806248540056623e-08
# db error:  1.734924139321044e-10

# %% [markdown]
# # LSTM: forward
# In the function `lstm_forward` in the file `cs231n/rnn_layers.py`, implement the `lstm_forward` function to run an LSTM forward on an entire timeseries of data.
#
# When you are done, run the following to check your implementation. You should see an error around `1e-7`.

# %%
N, D, H, T = 2, 5, 4, 3
x = np.linspace(-0.4, 0.6, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.4, 0.8, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.9, num=4*D*H).reshape(D, 4 * H)
Wh = np.linspace(-0.3, 0.6, num=4*H*H).reshape(H, 4 * H)
b = np.linspace(0.2, 0.7, num=4*H)

h, cache = lstm_forward(x, h0, Wx, Wh, b)

expected_h = np.asarray([
 [[ 0.01764008,  0.01823233,  0.01882671,  0.0194232 ],
  [ 0.11287491,  0.12146228,  0.13018446,  0.13902939],
  [ 0.31358768,  0.33338627,  0.35304453,  0.37250975]],
 [[ 0.45767879,  0.4761092,   0.4936887,   0.51041945],
  [ 0.6704845,   0.69350089,  0.71486014,  0.7346449 ],
  [ 0.81733511,  0.83677871,  0.85403753,  0.86935314]]])

print('h error: ', rel_error(expected_h, h))
# Out:
# h error:  8.610537452106624e-08

# %% [markdown]
# # LSTM: backward
# Implement the backward pass for an LSTM over an entire timeseries of data in the function `lstm_backward` in the file `cs231n/rnn_layers.py`. When you are done, run the following to perform numeric gradient checking on your implementation. You should see errors around `1e-7` or less.

# %%
from cs231n.rnn_layers import lstm_forward, lstm_backward
np.random.seed(231)

N, D, T, H = 2, 3, 10, 6

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, 4 * H)
Wh = np.random.randn(H, 4 * H)
b = np.random.randn(4 * H)

out, cache = lstm_forward(x, h0, Wx, Wh, b)

dout = np.random.randn(*out.shape)

dx, dh0, dWx, dWh, db = lstm_backward(dout, cache)

fx = lambda x: lstm_forward(x, h0, Wx, Wh, b)[0]
fh0 = lambda h0: lstm_forward(x, h0, Wx, Wh, b)[0]
fWx = lambda Wx: lstm_forward(x, h0, Wx, Wh, b)[0]
fWh = lambda Wh: lstm_forward(x, h0, Wx, Wh, b)[0]
fb = lambda b: lstm_forward(x, h0, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dh0_num = eval_numerical_gradient_array(fh0, h0, dout)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dout)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

print('dx error: ', rel_error(dx_num, dx))
print('dh0 error: ', rel_error(dh0_num, dh0))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  6.186232096167152e-09
# dh0 error:  6.791883730936431e-09
# dWx error:  3.301449507829467e-09
# dWh error:  1.5077886468004443e-06
# db error:  7.214753825317872e-10

# %% [markdown]
# # LSTM captioning model
#
# Now that you have implemented an LSTM, update the implementation of the `loss` method of the `CaptioningRNN` class in the file `cs231n/classifiers/rnn.py` to handle the case where `self.cell_type` is `lstm`. This should require adding less than 10 lines of code.
#
# Once you have done so, run the following to check your implementation. You should see a difference of less than `1e-10`.

# %%
N, D, W, H = 10, 20, 30, 40
word_to_idx = {'<NULL>': 0, 'cat': 2, 'dog': 3}
V = len(word_to_idx)
T = 13

model = CaptioningRNN(word_to_idx,
          input_dim=D,
          wordvec_dim=W,
          hidden_dim=H,
          cell_type='lstm',
          dtype=np.float64)

# Set all model parameters to fixed values
for k, v in model.params.items():
  model.params[k] = np.linspace(-1.4, 1.3, num=v.size).reshape(*v.shape)

features = np.linspace(-0.5, 1.7, num=N*D).reshape(N, D)
captions = (np.arange(N * T) % V).reshape(N, T)

loss, grads = model.loss(features, captions)
expected_loss = 9.82445935443

print('loss: ', loss)
print('expected loss: ', expected_loss)
print('difference: ', abs(loss - expected_loss))
# Out:
# loss:  9.824459354432264
# expected loss:  9.82445935443
# difference:  2.2648549702353193e-12

# %% [markdown]
# # Overfit LSTM captioning model
# Run the following to overfit an LSTM captioning model on the same small dataset as we used for the RNN previously. You should see losses less than 0.5.

# %%
np.random.seed(231)

small_data = load_coco_data(max_train=50)

small_lstm_model = CaptioningRNN(
          cell_type='lstm',
          word_to_idx=data['word_to_idx'],
          input_dim=data['train_features'].shape[1],
          hidden_dim=512,
          wordvec_dim=256,
          dtype=np.float32,
        )

small_lstm_solver = CaptioningSolver(small_lstm_model, small_data,
           update_rule='adam',
           num_epochs=50,
           batch_size=25,
           optim_config={
             'learning_rate': 5e-3,
           },
           lr_decay=0.995,
           verbose=True, print_every=10,
         )

small_lstm_solver.train()

# Plot the training losses
plt.plot(small_lstm_solver.loss_history)
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss history')
plt.show()
# Out:
# (Iteration 1 / 100) loss: 79.551150
# (Iteration 11 / 100) loss: 43.829099
# (Iteration 21 / 100) loss: 30.062605
# (Iteration 31 / 100) loss: 14.020145
# (Iteration 41 / 100) loss: 6.005285
# (Iteration 51 / 100) loss: 1.849795
# (Iteration 61 / 100) loss: 0.639324
# (Iteration 71 / 100) loss: 0.283563
# (Iteration 81 / 100) loss: 0.231855
# (Iteration 91 / 100) loss: 0.120608

# %% [markdown]
# # LSTM test-time sampling
# Modify the `sample` method of the `CaptioningRNN` class to handle the case where `self.cell_type` is `lstm`. This should take fewer than 10 lines of code.
#
# When you are done run the following to sample from your overfit LSTM model on some training and validation set samples.

# %%
for split in ['train', 'val']:
    minibatch = sample_coco_minibatch(small_data, split=split, batch_size=2)
    gt_captions, features, urls = minibatch
    gt_captions = decode_captions(gt_captions, data['idx_to_word'])

    sample_captions = small_lstm_model.sample(features)
    sample_captions = decode_captions(sample_captions, data['idx_to_word'])

    for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
        plt.imshow(image_from_url(url))
        plt.title('%s\n%s\nGT:%s' % (split, sample_caption, gt_caption))
        plt.axis('off')
        plt.show()

# %% [markdown]
# # Train a good captioning model (extra credit for 4803)
# Using the pieces you have implemented in this and the previous notebook, train a captioning model that gives decent qualitative results (better than the random garbage you saw with the overfit models) when sampling on the validation set. You can subsample the training set if you want; we just want to see samples on the validation set that are better than random.
#
# In addition to qualitatively evaluating your model by inspecting its results, you can also quantitatively evaluate your model using the BLEU unigram precision metric. In order to achieve full credit you should train a model that achieves a BLEU unigram score of >0.3. BLEU scores range from 0 to 1; the closer to 1, the better. Here's a reference to the [paper](http://www.aclweb.org/anthology/P02-1040.pdf) that introduces BLEU if you're interested in learning more about how it works.
#
# Feel free to use PyTorch for this section if you'd like to train faster on a GPU... though you can definitely get above 0.3 using your Numpy code. We're providing you the evaluation code that is compatible with the Numpy model as defined above... you should be able to adapt it for PyTorch if you go that route.
#
# Create the model in the file `cs231n/classifiers/mymodel.py`. You can base it after the `CaptioningRNN` class. Write a text comment in the delineated cell below explaining what you tried in your model.
#
# Also add a cell below that trains and tests your model. Make sure to include the call to evaluate_model which prints out your highest validation BLEU score for full credit.

# %%
def BLEU_score(gt_caption, sample_caption):
    """
    gt_caption: string, ground-truth caption
    sample_caption: string, your model's predicted caption
    Returns unigram BLEU score.
    """
    reference = [x for x in gt_caption.split(' ') 
                 if ('<END>' not in x and '<START>' not in x and '<UNK>' not in x)]
    hypothesis = [x for x in sample_caption.split(' ') 
                  if ('<END>' not in x and '<START>' not in x and '<UNK>' not in x)]
    BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis, weights = [1])
    return BLEUscore

def evaluate_model(model):
    """
    model: CaptioningRNN model
    Prints unigram BLEU score averaged over 1000 training and val examples.
    """
    BLEUscores = {}
    for split in ['train', 'val']:
        minibatch = sample_coco_minibatch(data, split=split, batch_size=1000)
        gt_captions, features, urls = minibatch
        gt_captions = decode_captions(gt_captions, data['idx_to_word'])

        sample_captions = model.sample(features)
        sample_captions = decode_captions(sample_captions, data['idx_to_word'])

        total_score = 0.0
        for gt_caption, sample_caption, url in zip(gt_captions, sample_captions, urls):
            total_score += BLEU_score(gt_caption, sample_caption)

        BLEUscores[split] = total_score / len(sample_captions)

    for split in BLEUscores:
        print('Average BLEU score for %s: %f' % (split, BLEUscores[split]))

# %% [markdown]
# # write a description of your model here:
# I implemented the evaluate function for Bleu score in the captionsolver class under train method to see the bleu score after every 10th iteration to see how well my hyperparameters are doing. This way i was able to quickly analyze when my model is overfitting and when it is underfitting.
# Initially the model overfits and my BleU score doesnt do well, but then I started changing learning parameter, but that also didnt help. I realize I need to increase my traning size, So then i increase the max_train size to 100000, because the model needs to look at all the images.
# Final with 1lac of max_train size, and learning rate of 1e-3 gave me the results after long iterations.

# %%
# write your code to train your model here.
# make sure to include the call to evaluate_model which prints out your highest validation BLEU score.
# data = load_coco_data(pca_features=True)
np.random.seed(231)
small_data2 = load_coco_data(max_train=100000)
good_lstm_model = CaptioningRNN(
          cell_type='lstm',
          word_to_idx=data['word_to_idx'],
          input_dim=data['train_features'].shape[1],
          hidden_dim=512,
          wordvec_dim=256 )

good_lstm_solver = CaptioningSolver(good_lstm_model, small_data2,
           update_rule='adam',
           num_epochs=50,
           batch_size=300,
           optim_config={
             'learning_rate': 1e-3,
           },
           lr_decay=1,
           verbose=True, print_every=10,
         )
good_lstm_solver.train()
# Out:
# (Iteration 1 / 16650) loss: 76.512785
# Average BLEU score for train: 0.053796
# Average BLEU score for val: 0.052547
# Difference in train and val BLEU score is  0.0012489687533114024
# (Iteration 11 / 16650) loss: 68.077276
# Average BLEU score for train: 0.055532
# Average BLEU score for val: 0.053442
# Difference in train and val BLEU score is  0.0020903368510800935
# (Iteration 21 / 16650) loss: 54.645203
# Average BLEU score for train: 0.055072
# Average BLEU score for val: 0.055254
# Difference in train and val BLEU score is  -0.00018201970443343374
# (Iteration 31 / 16650) loss: 51.163827
# Average BLEU score for train: 0.106109
# Average BLEU score for val: 0.105851
# Difference in train and val BLEU score is  0.00025735294117636143
# (Iteration 41 / 16650) loss: 50.287091
# Average BLEU score for train: 0.007557
# Average BLEU score for val: 0.009782
# Difference in train and val BLEU score is  -0.0022245548397921725
# (Iteration 51 / 16650) loss: 49.102843
# Average BLEU score for train: 0.003444
# Average BLEU score for val: 0.004132
# Difference in train and val BLEU score is  -0.0006874181720364744
# (Iteration 61 / 16650) loss: 46.130155
# Average BLEU score for train: 0.003247
# Average BLEU score for val: 0.003319
# Difference in train and val BLEU score is  -7.25174619795022e-05
# (Iteration 71 / 16650) loss: 45.115773
# Average BLEU score for train: 0.082357
# Average BLEU score for val: 0.081192
# Difference in train and val BLEU score is  0.0011651298893828876
# (Iteration 81 / 16650) loss: 44.005203
# Average BLEU score for train: 0.112364
# Average BLEU score for val: 0.111250
# Difference in train and val BLEU score is  0.0011142857142856788
# (Iteration 91 / 16650) loss: 42.274486
# Average BLEU score for train: 0.112433
# Average BLEU score for val: 0.112486
# Difference in train and val BLEU score is  -5.2380952381081425e-05
# (Iteration 101 / 16650) loss: 41.510075
# Average BLEU score for train: 0.102852
# Average BLEU score for val: 0.104874
# Difference in train and val BLEU score is  -0.0020214285714287017
# (Iteration 111 / 16650) loss: 39.362343
# Average BLEU score for train: 0.106938
# Average BLEU score for val: 0.105519
# Difference in train and val BLEU score is  0.0014190476190478751
# (Iteration 121 / 16650) loss: 37.871784
# Average BLEU score for train: 0.119698
# Average BLEU score for val: 0.119864
# Difference in train and val BLEU score is  -0.00016666666666656504
# (Iteration 131 / 16650) loss: 36.765185
# Average BLEU score for train: 0.108198
# Average BLEU score for val: 0.113233
# Difference in train and val BLEU score is  -0.005035714285714282
# (Iteration 141 / 16650) loss: 36.578958
# Average BLEU score for train: 0.108693
# Average BLEU score for val: 0.109640
# Difference in train and val BLEU score is  -0.0009476190476191138
# (Iteration 151 / 16650) loss: 36.221491
# Average BLEU score for train: 0.110331
# Average BLEU score for val: 0.113152
# Difference in train and val BLEU score is  -0.0028214285714286413
# (Iteration 161 / 16650) loss: 36.172265
# Average BLEU score for train: 0.108087
# Average BLEU score for val: 0.105265
# Difference in train and val BLEU score is  0.002822077922078059
# (Iteration 171 / 16650) loss: 34.059236
# Average BLEU score for train: 0.083991
# Average BLEU score for val: 0.081244
# Difference in train and val BLEU score is  0.0027467980295565186
# (Iteration 181 / 16650) loss: 34.997861
# Average BLEU score for train: 0.100156
# Average BLEU score for val: 0.099084
# Difference in train and val BLEU score is  0.001072051282051456
# (Iteration 191 / 16650) loss: 34.708261
# Average BLEU score for train: 0.095655
# Average BLEU score for val: 0.098772
# Difference in train and val BLEU score is  -0.003116923076923128
# (Iteration 201 / 16650) loss: 34.009456
# Average BLEU score for train: 0.112660
# Average BLEU score for val: 0.110233
# Difference in train and val BLEU score is  0.0024268398268396107
# (Iteration 211 / 16650) loss: 33.692329
# Average BLEU score for train: 0.113114
# Average BLEU score for val: 0.112238
# Difference in train and val BLEU score is  0.0008753846153847916
# (Iteration 221 / 16650) loss: 32.774109
# Average BLEU score for train: 0.111291
# Average BLEU score for val: 0.112050
# Difference in train and val BLEU score is  -0.0007592592592591124
# (Iteration 231 / 16650) loss: 32.725878
# Average BLEU score for train: 0.080182
# Average BLEU score for val: 0.084419
# Difference in train and val BLEU score is  -0.004236863711001543
# (Iteration 241 / 16650) loss: 31.194724
# Average BLEU score for train: 0.081264
# Average BLEU score for val: 0.083858
# Difference in train and val BLEU score is  -0.002594170771757054
# (Iteration 251 / 16650) loss: 32.465865
# Average BLEU score for train: 0.101397
# Average BLEU score for val: 0.104155
# Difference in train and val BLEU score is  -0.002758461538461418
# (Iteration 261 / 16650) loss: 31.788001
# Average BLEU score for train: 0.099736
# Average BLEU score for val: 0.100938
# Difference in train and val BLEU score is  -0.001202849002849088
# (Iteration 271 / 16650) loss: 31.882635
# Average BLEU score for train: 0.115286
# Average BLEU score for val: 0.112769
# Difference in train and val BLEU score is  0.002517094017094129
# (Iteration 281 / 16650) loss: 31.257389
# Average BLEU score for train: 0.103136
# Average BLEU score for val: 0.100763
# Difference in train and val BLEU score is  0.0023727920227919197
# (Iteration 291 / 16650) loss: 30.477113
# Average BLEU score for train: 0.107841
# Average BLEU score for val: 0.105510
# Difference in train and val BLEU score is  0.0023315811965812783
# (Iteration 301 / 16650) loss: 31.157326
# Average BLEU score for train: 0.105366
# Average BLEU score for val: 0.101158
# Difference in train and val BLEU score is  0.0042082837213871516
# (Iteration 311 / 16650) loss: 30.809403
# Average BLEU score for train: 0.093583
# Average BLEU score for val: 0.086889
# Difference in train and val BLEU score is  0.006693267651888074
# (Iteration 321 / 16650) loss: 29.741073
# Average BLEU score for train: 0.080971
# Average BLEU score for val: 0.079123
# Difference in train and val BLEU score is  0.0018482758620690515
# (Iteration 331 / 16650) loss: 30.615574
# Average BLEU score for train: 0.101379
# Average BLEU score for val: 0.099267
# Difference in train and val BLEU score is  0.0021118226600984474
# (Iteration 341 / 16650) loss: 29.470562
# Average BLEU score for train: 0.083156
# Average BLEU score for val: 0.084114
# Difference in train and val BLEU score is  -0.0009574712643675848
# (Iteration 351 / 16650) loss: 29.752151
# Average BLEU score for train: 0.081761
# Average BLEU score for val: 0.080060
# Difference in train and val BLEU score is  0.0017011494252872073
# (Iteration 361 / 16650) loss: 29.933636
# Average BLEU score for train: 0.087015
# Average BLEU score for val: 0.085812
# Difference in train and val BLEU score is  0.0012029556650245826
# (Iteration 371 / 16650) loss: 30.045493
# Average BLEU score for train: 0.077519
# Average BLEU score for val: 0.081222
# Difference in train and val BLEU score is  -0.0037025177887247407
# (Iteration 381 / 16650) loss: 29.121295
# Average BLEU score for train: 0.096403
# Average BLEU score for val: 0.095964
# Difference in train and val BLEU score is  0.000438950640674729
# (Iteration 391 / 16650) loss: 29.643437
# Average BLEU score for train: 0.082078
# Average BLEU score for val: 0.080373
# Difference in train and val BLEU score is  0.0017050119639041017
# (Iteration 401 / 16650) loss: 28.937667
# Average BLEU score for train: 0.085514
# Average BLEU score for val: 0.084710
# Difference in train and val BLEU score is  0.0008034482758620537
# (Iteration 411 / 16650) loss: 29.312577
# Average BLEU score for train: 0.078934
# Average BLEU score for val: 0.082169
# Difference in train and val BLEU score is  -0.003234482758620552
# (Iteration 421 / 16650) loss: 28.827288
# Average BLEU score for train: 0.085900
# Average BLEU score for val: 0.084759
# Difference in train and val BLEU score is  0.0011413793103450948
# (Iteration 431 / 16650) loss: 28.730817
# Average BLEU score for train: 0.077886
# Average BLEU score for val: 0.075974
# Difference in train and val BLEU score is  0.0019126436781607553
# (Iteration 441 / 16650) loss: 28.138362
# Average BLEU score for train: 0.080329
# Average BLEU score for val: 0.079390
# Difference in train and val BLEU score is  0.0009390804597700364
# (Iteration 451 / 16650) loss: 29.174410
# Average BLEU score for train: 0.084532
# Average BLEU score for val: 0.085062
# Difference in train and val BLEU score is  -0.0005298850574713132
# (Iteration 461 / 16650) loss: 29.415328
# Average BLEU score for train: 0.082529
# Average BLEU score for val: 0.081836
# Difference in train and val BLEU score is  0.0006931034482758058
# (Iteration 471 / 16650) loss: 28.722077
# Average BLEU score for train: 0.079882
# Average BLEU score for val: 0.077456
# Difference in train and val BLEU score is  0.0024252873563217897
# (Iteration 481 / 16650) loss: 27.198391
# Average BLEU score for train: 0.082579
# Average BLEU score for val: 0.081041
# Difference in train and val BLEU score is  0.0015379310344828395
# (Iteration 491 / 16650) loss: 28.147840
# Average BLEU score for train: 0.082468
# Average BLEU score for val: 0.082572
# Difference in train and val BLEU score is  -0.00010459770114930322
# (Iteration 501 / 16650) loss: 29.195641
# Average BLEU score for train: 0.085290
# Average BLEU score for val: 0.083306
# Difference in train and val BLEU score is  0.0019839080459769926
# (Iteration 511 / 16650) loss: 27.732254
# Average BLEU score for train: 0.086737
# Average BLEU score for val: 0.087005
# Difference in train and val BLEU score is  -0.0002678160919538375
# (Iteration 521 / 16650) loss: 27.313178
# Average BLEU score for train: 0.089757
# Average BLEU score for val: 0.092868
# Difference in train and val BLEU score is  -0.0031103448275862228
# (Iteration 531 / 16650) loss: 28.091101
# Average BLEU score for train: 0.082798
# Average BLEU score for val: 0.084340
# Difference in train and val BLEU score is  -0.0015425287356323064
# (Iteration 541 / 16650) loss: 28.993446
# Average BLEU score for train: 0.077545
# Average BLEU score for val: 0.075774
# Difference in train and val BLEU score is  0.0017712643678160223
# (Iteration 551 / 16650) loss: 27.427098
# Average BLEU score for train: 0.084879
# Average BLEU score for val: 0.085933
# Difference in train and val BLEU score is  -0.0010538613812751813
# (Iteration 561 / 16650) loss: 27.835226
# Average BLEU score for train: 0.084485
# Average BLEU score for val: 0.083844
# Difference in train and val BLEU score is  0.000641379310344678
# (Iteration 571 / 16650) loss: 28.029334
# Average BLEU score for train: 0.084986
# Average BLEU score for val: 0.083768
# Difference in train and val BLEU score is  0.0012185550082102203
# (Iteration 581 / 16650) loss: 27.443562
# Average BLEU score for train: 0.080337
# Average BLEU score for val: 0.079133
# Difference in train and val BLEU score is  0.0012035303776683215
# (Iteration 591 / 16650) loss: 28.187435
# Average BLEU score for train: 0.083301
# Average BLEU score for val: 0.083237
# Difference in train and val BLEU score is  6.428571428593322e-05
# (Iteration 601 / 16650) loss: 27.794266
# Average BLEU score for train: 0.081482
# Average BLEU score for val: 0.084695
# Difference in train and val BLEU score is  -0.003213546798029515
# (Iteration 611 / 16650) loss: 27.625552
# Average BLEU score for train: 0.085548
# Average BLEU score for val: 0.084693
# Difference in train and val BLEU score is  0.0008548166392993439
# (Iteration 621 / 16650) loss: 27.366096
# Average BLEU score for train: 0.083125
# Average BLEU score for val: 0.084824
# Difference in train and val BLEU score is  -0.0016988505747125848
# (Iteration 631 / 16650) loss: 27.762143
# Average BLEU score for train: 0.085140
# Average BLEU score for val: 0.086864
# Difference in train and val BLEU score is  -0.001723809523809669
# (Iteration 641 / 16650) loss: 26.851792
# Average BLEU score for train: 0.079128
# Average BLEU score for val: 0.081615
# Difference in train and val BLEU score is  -0.002487356321839093
# (Iteration 651 / 16650) loss: 26.620749
# Average BLEU score for train: 0.080633
# Average BLEU score for val: 0.078694
# Difference in train and val BLEU score is  0.0019390804597700234
# (Iteration 661 / 16650) loss: 26.141276
# Average BLEU score for train: 0.090280
# Average BLEU score for val: 0.090247
# Difference in train and val BLEU score is  3.275862068971569e-05
# (Iteration 671 / 16650) loss: 26.606734
# Average BLEU score for train: 0.083569
# Average BLEU score for val: 0.081886
# Difference in train and val BLEU score is  0.0016827586206895478
# (Iteration 681 / 16650) loss: 26.782038
# Average BLEU score for train: 0.082256
# Average BLEU score for val: 0.085647
# Difference in train and val BLEU score is  -0.0033908045977011914
# (Iteration 691 / 16650) loss: 26.477262
# Average BLEU score for train: 0.094627
# Average BLEU score for val: 0.098696
# Difference in train and val BLEU score is  -0.004068791942432287
# (Iteration 701 / 16650) loss: 26.682881
# Average BLEU score for train: 0.082967
# Average BLEU score for val: 0.083227
# Difference in train and val BLEU score is  -0.00025960591133000754
# (Iteration 711 / 16650) loss: 26.731201
# Average BLEU score for train: 0.086187
# Average BLEU score for val: 0.087859
# Difference in train and val BLEU score is  -0.0016724137931036498
# (Iteration 721 / 16650) loss: 27.290718
# Average BLEU score for train: 0.085213
# Average BLEU score for val: 0.083285
# Difference in train and val BLEU score is  0.0019275862068965643
# (Iteration 731 / 16650) loss: 26.415401
# Average BLEU score for train: 0.083914
# Average BLEU score for val: 0.082449
# Difference in train and val BLEU score is  0.0014643678160918272
# (Iteration 741 / 16650) loss: 26.509080
# Average BLEU score for train: 0.084476
# Average BLEU score for val: 0.084049
# Difference in train and val BLEU score is  0.0004264367816091408
# (Iteration 751 / 16650) loss: 26.487593
# Average BLEU score for train: 0.081111
# Average BLEU score for val: 0.077371
# Difference in train and val BLEU score is  0.0037402298850575944
# (Iteration 761 / 16650) loss: 25.885875
# Average BLEU score for train: 0.087185
# Average BLEU score for val: 0.085985
# Difference in train and val BLEU score is  0.0012007389162561471
# (Iteration 771 / 16650) loss: 25.518479
# Average BLEU score for train: 0.077811
# Average BLEU score for val: 0.075808
# Difference in train and val BLEU score is  0.002003448275862005
# (Iteration 781 / 16650) loss: 26.511946
# Average BLEU score for train: 0.087953
# Average BLEU score for val: 0.086440
# Difference in train and val BLEU score is  0.0015126436781609243
# (Iteration 791 / 16650) loss: 26.092233
# Average BLEU score for train: 0.085340
# Average BLEU score for val: 0.084961
# Difference in train and val BLEU score is  0.000379310344827688
# (Iteration 801 / 16650) loss: 26.415936
# Average BLEU score for train: 0.087414
# Average BLEU score for val: 0.086218
# Difference in train and val BLEU score is  0.0011962233169129505
# (Iteration 811 / 16650) loss: 26.828772
# Average BLEU score for train: 0.086715
# Average BLEU score for val: 0.084170
# Difference in train and val BLEU score is  0.0025443349753691835
# (Iteration 821 / 16650) loss: 26.863449
# Average BLEU score for train: 0.087066
# Average BLEU score for val: 0.083067
# Difference in train and val BLEU score is  0.003998768472906464
# (Iteration 831 / 16650) loss: 25.563962
# Average BLEU score for train: 0.087848
# Average BLEU score for val: 0.084472
# Difference in train and val BLEU score is  0.0033766009852217727
# (Iteration 841 / 16650) loss: 26.851231
# Average BLEU score for train: 0.082772
# Average BLEU score for val: 0.084693
# Difference in train and val BLEU score is  -0.0019206896551723779
# (Iteration 851 / 16650) loss: 26.312038
# Average BLEU score for train: 0.083679
# Average BLEU score for val: 0.083938
# Difference in train and val BLEU score is  -0.0002586206896549037
# (Iteration 861 / 16650) loss: 26.604260
# Average BLEU score for train: 0.087239
# Average BLEU score for val: 0.083855
# Difference in train and val BLEU score is  0.003383990147783192
# (Iteration 871 / 16650) loss: 26.132024
# Average BLEU score for train: 0.089118
# Average BLEU score for val: 0.086309
# Difference in train and val BLEU score is  0.0028083743842365755
# (Iteration 881 / 16650) loss: 25.905669
# Average BLEU score for train: 0.089344
# Average BLEU score for val: 0.086569
# Difference in train and val BLEU score is  0.0027751231527092246
# (Iteration 891 / 16650) loss: 26.912422
# Average BLEU score for train: 0.084863
# Average BLEU score for val: 0.082484
# Difference in train and val BLEU score is  0.0023793833242110873
# (Iteration 901 / 16650) loss: 25.886046
# Average BLEU score for train: 0.087406
# Average BLEU score for val: 0.085355
# Difference in train and val BLEU score is  0.002050574712643388
# (Iteration 911 / 16650) loss: 25.285070
# Average BLEU score for train: 0.088526
# Average BLEU score for val: 0.085855
# Difference in train and val BLEU score is  0.0026712643678160203
# (Iteration 921 / 16650) loss: 24.962257
# Average BLEU score for train: 0.088115
# Average BLEU score for val: 0.083757
# Difference in train and val BLEU score is  0.004357471264367821
# (Iteration 931 / 16650) loss: 25.072538
# Average BLEU score for train: 0.081393
# Average BLEU score for val: 0.085532
# Difference in train and val BLEU score is  -0.004139080459770211
# (Iteration 941 / 16650) loss: 24.834605
# Average BLEU score for train: 0.090369
# Average BLEU score for val: 0.089220
# Difference in train and val BLEU score is  0.0011499178981939084
# (Iteration 951 / 16650) loss: 24.621629
# Average BLEU score for train: 0.094539
# Average BLEU score for val: 0.093082
# Difference in train and val BLEU score is  0.001457213871696797
# (Iteration 961 / 16650) loss: 26.412811
# Average BLEU score for train: 0.117740
# Average BLEU score for val: 0.115469
# Difference in train and val BLEU score is  0.0022710180623974063
# (Iteration 971 / 16650) loss: 24.979272
# Average BLEU score for train: 0.088351
# Average BLEU score for val: 0.087230
# Difference in train and val BLEU score is  0.0011206896551724937
# (Iteration 981 / 16650) loss: 25.333525
# Average BLEU score for train: 0.089512
# Average BLEU score for val: 0.088515
# Difference in train and val BLEU score is  0.0009969622331691963
# (Iteration 991 / 16650) loss: 25.749301
# Average BLEU score for train: 0.088402
# Average BLEU score for val: 0.084126
# Difference in train and val BLEU score is  0.004275862068965408
# (Iteration 1001 / 16650) loss: 25.204308
# Average BLEU score for train: 0.084701
# Average BLEU score for val: 0.079226
# Difference in train and val BLEU score is  0.005474712643678117
# (Iteration 1011 / 16650) loss: 24.650243
# Average BLEU score for train: 0.083598
# Average BLEU score for val: 0.085052
# Difference in train and val BLEU score is  -0.0014540229885058736
# (Iteration 1021 / 16650) loss: 25.148533
# Average BLEU score for train: 0.094331
# Average BLEU score for val: 0.095493
# Difference in train and val BLEU score is  -0.001162068965517099
# (Iteration 1031 / 16650) loss: 25.965568
# Average BLEU score for train: 0.083451
# Average BLEU score for val: 0.085593
# Difference in train and val BLEU score is  -0.0021422003284072705
# (Iteration 1041 / 16650) loss: 25.869901
# Average BLEU score for train: 0.085477
# Average BLEU score for val: 0.082023
# Difference in train and val BLEU score is  0.0034540229885059587
# (Iteration 1051 / 16650) loss: 25.706667
# Average BLEU score for train: 0.084014
# Average BLEU score for val: 0.083745
# Difference in train and val BLEU score is  0.00026921182266002874
# (Iteration 1061 / 16650) loss: 24.407620
# Average BLEU score for train: 0.097420
# Average BLEU score for val: 0.094879
# Difference in train and val BLEU score is  0.00254022988505756
# (Iteration 1071 / 16650) loss: 23.854423
# Average BLEU score for train: 0.094817
# Average BLEU score for val: 0.096808
# Difference in train and val BLEU score is  -0.0019911975636113105
# (Iteration 1081 / 16650) loss: 25.227175
# Average BLEU score for train: 0.086176
# Average BLEU score for val: 0.084936
# Difference in train and val BLEU score is  0.0012402298850576199
# (Iteration 1091 / 16650) loss: 24.700606
# Average BLEU score for train: 0.086392
# Average BLEU score for val: 0.085229
# Difference in train and val BLEU score is  0.001163218390804438
# (Iteration 1101 / 16650) loss: 24.849424
# Average BLEU score for train: 0.088495
# Average BLEU score for val: 0.084262
# Difference in train and val BLEU score is  0.004233333333333228
# (Iteration 1111 / 16650) loss: 24.241071
# Average BLEU score for train: 0.088207
# Average BLEU score for val: 0.085864
# Difference in train and val BLEU score is  0.002342528735632232
# (Iteration 1121 / 16650) loss: 25.272117
# Average BLEU score for train: 0.089248
# Average BLEU score for val: 0.086068
# Difference in train and val BLEU score is  0.003180459770114802
# (Iteration 1131 / 16650) loss: 24.481606
# Average BLEU score for train: 0.093190
# Average BLEU score for val: 0.087130
# Difference in train and val BLEU score is  0.006059760992519592
# (Iteration 1141 / 16650) loss: 25.257430
# Average BLEU score for train: 0.101666
# Average BLEU score for val: 0.096579
# Difference in train and val BLEU score is  0.005086945812807789
# (Iteration 1151 / 16650) loss: 24.660716
# Average BLEU score for train: 0.091256
# Average BLEU score for val: 0.085250
# Difference in train and val BLEU score is  0.006005573800401343
# (Iteration 1161 / 16650) loss: 25.075980
# Average BLEU score for train: 0.081712
# Average BLEU score for val: 0.083849
# Difference in train and val BLEU score is  -0.002137192118226744
# (Iteration 1171 / 16650) loss: 23.524729
# Average BLEU score for train: 0.092368
# Average BLEU score for val: 0.093070
# Difference in train and val BLEU score is  -0.0007018883415434718
# (Iteration 1181 / 16650) loss: 24.701108
# Average BLEU score for train: 0.094214
# Average BLEU score for val: 0.092503
# Difference in train and val BLEU score is  0.0017103448275861965
# (Iteration 1191 / 16650) loss: 24.768657
# Average BLEU score for train: 0.089130
# Average BLEU score for val: 0.087300
# Difference in train and val BLEU score is  0.0018298850574711562
# (Iteration 1201 / 16650) loss: 24.581477
# Average BLEU score for train: 0.105520
# Average BLEU score for val: 0.106027
# Difference in train and val BLEU score is  -0.0005071225071224261
# (Iteration 1211 / 16650) loss: 24.785977
# Average BLEU score for train: 0.087225
# Average BLEU score for val: 0.086607
# Difference in train and val BLEU score is  0.0006183908045976072
# (Iteration 1221 / 16650) loss: 24.939197
# Average BLEU score for train: 0.086584
# Average BLEU score for val: 0.087230
# Difference in train and val BLEU score is  -0.000645977011494131
# (Iteration 1231 / 16650) loss: 24.078460
# Average BLEU score for train: 0.085110
# Average BLEU score for val: 0.088662
# Difference in train and val BLEU score is  -0.003551724137930923
# (Iteration 1241 / 16650) loss: 24.665725
# Average BLEU score for train: 0.086900
# Average BLEU score for val: 0.085479
# Difference in train and val BLEU score is  0.001420689655172419
# (Iteration 1251 / 16650) loss: 24.612927
# Average BLEU score for train: 0.083577
# Average BLEU score for val: 0.080560
# Difference in train and val BLEU score is  0.0030172413793102815
# (Iteration 1261 / 16650) loss: 24.732859
# Average BLEU score for train: 0.118613
# Average BLEU score for val: 0.119284
# Difference in train and val BLEU score is  -0.0006713471713474389
# (Iteration 1271 / 16650) loss: 23.645640
# Average BLEU score for train: 0.088398
# Average BLEU score for val: 0.090193
# Difference in train and val BLEU score is  -0.0017954022988507373
# (Iteration 1281 / 16650) loss: 24.282888
# Average BLEU score for train: 0.091618
# Average BLEU score for val: 0.085094
# Difference in train and val BLEU score is  0.006524137931034374
# (Iteration 1291 / 16650) loss: 24.531189
# Average BLEU score for train: 0.089542
# Average BLEU score for val: 0.087309
# Difference in train and val BLEU score is  0.0022326026272576904
# (Iteration 1301 / 16650) loss: 24.416990
# Average BLEU score for train: 0.121265
# Average BLEU score for val: 0.117600
# Difference in train and val BLEU score is  0.003665445665445591
# (Iteration 1311 / 16650) loss: 24.420007
# Average BLEU score for train: 0.085165
# Average BLEU score for val: 0.086505
# Difference in train and val BLEU score is  -0.0013401477832511166
# (Iteration 1321 / 16650) loss: 24.763796
# Average BLEU score for train: 0.092832
# Average BLEU score for val: 0.084862
# Difference in train and val BLEU score is  0.007969868637110078
# (Iteration 1331 / 16650) loss: 24.963264
# Average BLEU score for train: 0.089429
# Average BLEU score for val: 0.090942
# Difference in train and val BLEU score is  -0.0015126436781608965
# (Iteration 1341 / 16650) loss: 24.305354
# Average BLEU score for train: 0.106461
# Average BLEU score for val: 0.104166
# Difference in train and val BLEU score is  0.0022951568355017854
# (Iteration 1351 / 16650) loss: 23.478862
# Average BLEU score for train: 0.086675
# Average BLEU score for val: 0.083906
# Difference in train and val BLEU score is  0.002768965517241373
# (Iteration 1361 / 16650) loss: 24.647107
# Average BLEU score for train: 0.086138
# Average BLEU score for val: 0.087074
# Difference in train and val BLEU score is  -0.0009356321839080889
# (Iteration 1371 / 16650) loss: 24.174549
# Average BLEU score for train: 0.097944
# Average BLEU score for val: 0.096791
# Difference in train and val BLEU score is  0.0011521900832243553
# (Iteration 1381 / 16650) loss: 24.316431
# Average BLEU score for train: 0.082990
# Average BLEU score for val: 0.083343
# Difference in train and val BLEU score is  -0.0003528735632184199
# (Iteration 1391 / 16650) loss: 24.782471
# Average BLEU score for train: 0.098154
# Average BLEU score for val: 0.096630
# Difference in train and val BLEU score is  0.0015248038679073067
# (Iteration 1401 / 16650) loss: 23.021588
# Average BLEU score for train: 0.097206
# Average BLEU score for val: 0.093386
# Difference in train and val BLEU score is  0.0038202279202280143
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-592cb8692fc0> in <module>
#      21            verbose=True, print_every=10,
#      22          )
# ---> 23 good_lstm_solver.train()
#
# ~/Desktop/DL/AS_3/assignment/cs231n/captioning_solver.py in train(self)
#     254
#     255         for t in range(num_iterations):
# --> 256             self._step()
#     257
#     258             # Maybe print training loss
#
# ~/Desktop/DL/AS_3/assignment/cs231n/captioning_solver.py in _step(self)
#     149
#     150         # Compute loss and gradient
# --> 151         loss, grads = self.model.loss(features, captions)
#     152         self.loss_history.append(loss)
#     153
#
# ~/Desktop/DL/AS_3/assignment/cs231n/classifiers/rnn.py in loss(self, features, captions)
#     144             h,cache_rnn = rnn_forward(word_vec,h0,Wx,Wh,b)
#     145         if self.cell_type == 'lstm':
# --> 146             h,cache_lstm = lstm_forward(word_vec,h0,Wx,Wh,b)
#     147
#     148         scores,cache_scores = temporal_affine_forward(h,W_vocab,b_vocab)
#
# ~/Desktop/DL/AS_3/assignment/cs231n/rnn_layers.py in lstm_forward(x, h0, Wx, Wh, b)
#     373     cache = []
#     374     for i in range(T):
# --> 375         next_h,next_c,next_cache = lstm_step_forward(x[:,i,:], prev_h, prev_c, Wx, Wh, b)
#     376         cache.append(next_cache)
#     377         prev_h = next_h
#
# ~/Desktop/DL/AS_3/assignment/cs231n/rnn_layers.py in lstm_step_forward(x, prev_h, prev_c, Wx, Wh, b)
#     271     H = prev_h.shape[1]
#     272     # activation vector
# --> 273     a = np.dot(x,Wx) + np.dot(prev_h,Wh) + np.tile(b,(N,1))
#     274     i=sigmoid(a[:,:H])
#     275     f=sigmoid(a[:,H:2*H])
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
